# %%
import numpy as np
import sys

# generate random orders
def RandomlizeOrder(size):
    # 1,2: origin location
    # 3,4: destination
    # 5: ready by pickup time
    # 6: restaurant number
    res = []
    for i in range(size):
        res += [(np.random.randint(100),np.random.randint(100),np.random.randint(100),np.random.randint(100),np.random.randint(30),np.random.randint(10))]
    return res

# generate random courier locations
def RandomlizeCourier(size):
    # 1,2: courier geolocation
    res = []
    for i in range(size):
        res += [(np.random.randint(100),np.random.randint(100))]
    return res

# sort order by starting time
def sortOrders(orders):
    orders.sort(key=lambda x: x[4])

# simulate a travel time between restaurant and couriers
# call google api for accurate estimation in the future
def getDistance(couriers,orders):
    return np.random.randint(100)

# batching algorithm for initial batching
# loop through the orders and assign the each order to the closest courier one at a time
def initBatch(orders, couriers):
    batch = []
    assigned = set()
    for i in range(len(couriers)):
        minDis = sys.maxsize
        assign = -1
        for j in range(len(orders)):
            dis = getDistance(couriers, orders)
            if (dis < minDis and j not in assigned):
                assign = j
                minDis = dis
        assigned.add(assign)
        batch += [[assign]]
    return batch

# initial the batch by lookingforward orders that become ready within 20 mins and assign them 
# greedily to each courier's batch
def assignGreedy(orders, couriers, batches):
    assignedOrder = set()
    for batch in batches:
        assignedOrder.add(batch[0])
        
    for batch in batches:
        assigned = set()
        MaxTime = 0
        for b in batch:
            if (orders[b][4] > MaxTime):
                MaxTime = orders[b][4]
            assigned.add(orders[b][5])
        for i in range(len(orders)):
            order = orders[i]
            if (order[5] in assigned) and (order[4] < MaxTime + 20) and i not in assignedOrder:
                batch += [i]
                assignedOrder.add(i)
                assigned.add(order[5])

# objective function
# assign a score according to the overall lateness of each batch
def score(orders):
    # the objective function = delivery time + c * orders in batch (lateness)
    return 0

# trip swap
# perform three kinds of swap and see if the batch are scored higher
# at each iteration, perform the swap that most improves the objective
def swap():
    return 0

# swap an order in Batch A with an order in batch B
def swapOne():
    return 0

# remove an order from batch A and add it to batch B
def swapTwo():
    return 0

# remove an order from batch A and create a new batch
def swapThree():
    return 0

# %%
print("************************************")
print("Starting dispatching algorithm...")

numCouriers = input("Enter the number of the couriers ")
couriers = RandomlizeCourier(int(numCouriers))
print("************************************")
print("Initializing " + str(numCouriers) + " couriers....")
print()

numOrders = input("Enter the number of the orders ")
orders = RandomlizeOrder(int(numOrders))
print("************************************")
print("Initializing " + str(numOrders) +  " orders....")
print()

sortOrders(orders)
batch = initBatch(orders, couriers)

print("************************************")
print("Assigning orders according to their distance to the couriers...")
print("This is the first batch for first order:")
print(batch)
print()

print("************************************")
print("Assigning greedy algorithm to complete the initial batches...")
assignGreedy(orders,couriers, batch)
for i in range(len(couriers)):
    print("couriers " + str(i) + " got the following orders:")
    print(batch[i])
print()
# Out:
# ************************************
# Starting dispatching algorithm...
# Enter the number of the couriers 100
# ************************************
# Initializing 100 couriers....
#
# Enter the number of the orders 100
# ************************************
# Initializing 100 orders....
#
# ************************************
# Assigning orders according to their distance to the couriers...
# This is the first batch for first order:
# [[10], [2], [76], [14], [13], [42], [50], [33], [15], [93], [21], [58], [78], [87], [31], [64], [36], [26], [38], [46], [4], [61], [44], [16], [29], [68], [75], [48], [6], [37], [27], [73], [18], [20], [84], [43], [59], [77], [69], [53], [8], [88], [28], [71], [30], [19], [11], [55], [40], [66], [49], [98], [94], [95], [90], [81], [9], [56], [32], [60], [25], [63], [1], [57], [83], [91], [62], [0], [67], [89], [80], [3], [22], [39], [82], [65], [12], [34], [79], [35], [17], [92], [7], [52], [41], [5], [24], [85], [54], [72], [70], [51], [86], [45], [97], [47], [96], [23], [99], [74]]
#
# ************************************
# Assigning greedy algorithm to complete the initial batches...
# couriers 0 got the following orders:
# [10]
# couriers 1 got the following orders:
# [2]
# couriers 2 got the following orders:
# [76]
# couriers 3 got the following orders:
# [14]
# couriers 4 got the following orders:
# [13]
# couriers 5 got the following orders:
# [42]
# couriers 6 got the following orders:
# [50]
# couriers 7 got the following orders:
# [33]
# couriers 8 got the following orders:
# [15]
# couriers 9 got the following orders:
# [93]
# couriers 10 got the following orders:
# [21]
# couriers 11 got the following orders:
# [58]
# couriers 12 got the following orders:
# [78]
# couriers 13 got the following orders:
# [87]
# couriers 14 got the following orders:
# [31]
# couriers 15 got the following orders:
# [64]
# couriers 16 got the following orders:
# [36]
# couriers 17 got the following orders:
# [26]
# couriers 18 got the following orders:
# [38]
# couriers 19 got the following orders:
# [46]
# couriers 20 got the following orders:
# [4]
# couriers 21 got the following orders:
# [61]
# couriers 22 got the following orders:
# [44]
# couriers 23 got the following orders:
# [16]
# couriers 24 got the following orders:
# [29]
# couriers 25 got the following orders:
# [68]
# couriers 26 got the following orders:
# [75]
# couriers 27 got the following orders:
# [48]
# couriers 28 got the following orders:
# [6]
# couriers 29 got the following orders:
# [37]
# couriers 30 got the following orders:
# [27]
# couriers 31 got the following orders:
# [73]
# couriers 32 got the following orders:
# [18]
# couriers 33 got the following orders:
# [20]
# couriers 34 got the following orders:
# [84]
# couriers 35 got the following orders:
# [43]
# couriers 36 got the following orders:
# [59]
# couriers 37 got the following orders:
# [77]
# couriers 38 got the following orders:
# [69]
# couriers 39 got the following orders:
# [53]
# couriers 40 got the following orders:
# [8]
# couriers 41 got the following orders:
# [88]
# couriers 42 got the following orders:
# [28]
# couriers 43 got the following orders:
# [71]
# couriers 44 got the following orders:
# [30]
# couriers 45 got the following orders:
# [19]
# couriers 46 got the following orders:
# [11]
# couriers 47 got the following orders:
# [55]
# couriers 48 got the following orders:
# [40]
# couriers 49 got the following orders:
# [66]
# couriers 50 got the following orders:
# [49]
# couriers 51 got the following orders:
# [98]
# couriers 52 got the following orders:
# [94]
# couriers 53 got the following orders:
# [95]
# couriers 54 got the following orders:
# [90]
# couriers 55 got the following orders:
# [81]
# couriers 56 got the following orders:
# [9]
# couriers 57 got the following orders:
# [56]
# couriers 58 got the following orders:
# [32]
# couriers 59 got the following orders:
# [60]
# couriers 60 got the following orders:
# [25]
# couriers 61 got the following orders:
# [63]
# couriers 62 got the following orders:
# [1]
# couriers 63 got the following orders:
# [57]
# couriers 64 got the following orders:
# [83]
# couriers 65 got the following orders:
# [91]
# couriers 66 got the following orders:
# [62]
# couriers 67 got the following orders:
# [0]
# couriers 68 got the following orders:
# [67]
# couriers 69 got the following orders:
# [89]
# couriers 70 got the following orders:
# [80]
# couriers 71 got the following orders:
# [3]
# couriers 72 got the following orders:
# [22]
# couriers 73 got the following orders:
# [39]
# couriers 74 got the following orders:
# [82]
# couriers 75 got the following orders:
# [65]
# couriers 76 got the following orders:
# [12]
# couriers 77 got the following orders:
# [34]
# couriers 78 got the following orders:
# [79]
# couriers 79 got the following orders:
# [35]
# couriers 80 got the following orders:
# [17]
# couriers 81 got the following orders:
# [92]
# couriers 82 got the following orders:
# [7]
# couriers 83 got the following orders:
# [52]
# couriers 84 got the following orders:
# [41]
# couriers 85 got the following orders:
# [5]
# couriers 86 got the following orders:
# [24]
# couriers 87 got the following orders:
# [85]
# couriers 88 got the following orders:
# [54]
# couriers 89 got the following orders:
# [72]
# couriers 90 got the following orders:
# [70]
# couriers 91 got the following orders:
# [51]
# couriers 92 got the following orders:
# [86]
# couriers 93 got the following orders:
# [45]
# couriers 94 got the following orders:
# [97]
# couriers 95 got the following orders:
# [47]
# couriers 96 got the following orders:
# [96]
# couriers 97 got the following orders:
# [23]
# couriers 98 got the following orders:
# [99]
# couriers 99 got the following orders:
# [74]
